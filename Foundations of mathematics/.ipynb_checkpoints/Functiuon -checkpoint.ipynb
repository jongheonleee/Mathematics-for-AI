# %%
'''
함수란?
    > 첫번째 집합의 임의의 한 원소를 두 번째 집합의 원소 하나에 대응시키는 관계
    > 정의역 x에 대해 공역 y에 하나만 대응됨
    
함수와 방정식

    > 함수: x와 y 변수가 있을 때 x값에 따라 y값이 결정
    > 방정식: 변수를 포함하는 등식에서 변수 값에 따라 참/거짓이 성립
    
둘의 관계
- 실수 범위에서 모두 좌표평면 상에 표현가능
- 방정식은 함수를 포괄하는 개념
- 모든 함수는 방정식으로 바꾸어서 표현가능

* 고급함수

-일차함수: y=ax + b a(기울기)에 따라 그래프의 그림이 다르게 나타남(양수일때 증가, 값이 크면 y축에 가까움/음수일때는 반대로)

-직선의 방정식: 기울기가 t고 한점(x1, y1)을 지나는 직선의 방정식은 y-y1 = t(x-x1)

-이차함수: y = ax^2 + bx + c (a != 0) a가 양수일때 아래로 볼록, 값이 크면 좁아짐/음수일때는 반대로
'''
